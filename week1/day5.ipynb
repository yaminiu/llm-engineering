# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt
from openai import OpenAI
import sys
import json
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents

# Optional: for pretty markdown display in Jupyter/IPython
try:
    from IPython.display import Markdown, display, update_display
except ImportError:
    Markdown = display = update_display = None

# %%
links = fetch_website_links("https://www.ing.com.au")
links
# Out:
# ['/index.html',
#  '#',
#  '#',
#  '#',
#  '#',
#  '#',
#  'javascript:openJointInviteModal()',
#  '/securebanking/',
#  'javascript:openJointInviteModal()',
#  '/everyday-banking.html',
#  '#menu-everyday-banking',
#  '#menu-personal-savings',
#  '#menu-business-savings',
#  '#',
#  '/everyday-banking.html',
#  '#',
#  '/savings.html',
#  '/savings/savings-maximiser.html',
#  '/savings/term-deposit.html',
#  '/savings/savings-accelerator.html',
#  '#',
#  '/business.html',
#  '/business/business-optimiser.html',
#  '/business/term-deposit.html',
#  '/business/wholesale-term-deposit.html',
#  '/savings/budgeting-planning.html',
#  '/everyday-banking.html#ING-content-5',
#  '/mobile-banking.html',
#  '/savings/budgeting-strategy.html',
#  '/everyday-banking/everyday-round-up.html',
#  '/everyday-banking/pay-id.html',
#  '/everyday-banking/card-management.html',
#  '/savings/budgeting-planning.html',
#  '/savings.html#ING-content-2',
#  '/savings/compare-savings.html',
#  '/savings/budgeting-strategy.html',
#  '/calculators-and-tools.html#ING-content-2',
#  '/rates-and-fees/savings-interest-rates.html',
#  '/rates-and-fees/term-deposit-rates.html',
#  '/calculators-and-tools.html#ING-content-2',
#  '/rates-and-fees/business-banking-rates.html',
#  '/credit-cards.html',
#  '/credit-cards.html',
#  '/credit-cards/orange-one.html',
#  '/credit-cards/orange-one-platinum.html',
#  '/mobile-banking.html',
#  '/mobile/apple-pay/applepay.html',
#  '/mobile/google-pay/googlepay.html',
#  '/rates-and-fees/credit-cards-rates.html',
#  '/credit-cards/compare-credit-cards.html',
#  '/personal-loans.html',
#  '#menu-personal-loans',
#  '#',
#  '/personal-loans.html',
#  '/personal-loans/personal-loan-for-a-car.html',
#  '/personal-loans/personal-loan-for-home-renovations.html',
#  '/personal-loans/personal-loan-for-a-wedding.html',
#  '/personal-loans/personal-loan-for-a-holiday.html',
#  '/personal-loans/personal-loan-for-debt-consolidation.html',
#  '/personal-loans/calculators/personal-loan-borrowing-power-calculator.html',
#  '/personal-loans/calculators/personal-loan-repayments-calculator.html',
#  '/personal-loans/calculators/compare-personal-loans.html',
#  '/rates-and-fees/personal-loan-rates.html',
#  '/personal-loans.html#ING-content-4',
#  '/home-loans.html',
#  '#menu-home-loans',
#  '#menu-commercial-loans',
#  '#',
#  '/home-loans.html',
#  '/home-loans/mortgage-simplifier.html',
#  '/home-loans/orange-advantage.html',
#  '/home-loans/fixed-rate-home-loan.html',
#  '/home-loans/green-upgrade-loan.html',
#  '#',
#  '/home-loans/commercial-loan.html',
#  '/home-loans/business-green-upgrade-loan.html',
#  '/home-loans/manage-my-loan.html?pid=vis:meganav:hl:manage',
#  '/home-loans.html#HL-content-8',
#  '/everyday-banking/everyday-round-up.html',
#  '/home-loans/compare.html',
#  '/calculators-and-tools.html#ING-content-3',
#  '/home-loans/calculators/borrowing-power.html',
#  '/home-loans/calculators/repayments.html',
#  '/rates-and-fees/home-loan-rates.html',
#  '/home-loans/home-loan-variations.html',
#  '/rates-and-fees/home-loan-reference-rates.html',
#  '/insurance.html',
#  '#menu-ing-insurance',
#  '#menu-car-insurance',
#  '#menu-health-insurance',
#  '#menu-home-and-contents-insurance',
#  '#menu-motorcycle-insurance',
#  '#menu-pet-insurance',
#  '#menu-travel-insurance',
#  '#',
#  '/insurance.html',
#  '#',
#  '/insurance/car-insurance.html',
#  '/insurance/car-insurance/comprehensive-car-insurance.html',
#  '/insurance/car-insurance/third-party-car-insurance.html',
#  '#',
#  '/insurance/health-insurance.html',
#  '#',
#  '/insurance/home-and-contents-insurance.html',
#  '#',
#  '/insurance/motorcycle-insurance.html',
#  '#',
#  '/insurance/pet-insurance.html',
#  '#',
#  '/insurance/travel-insurance.html',
#  '/insurance/claims.html?pid=vis:meganav:ins:claim',
#  '/help-and-support/documents-and-forms/insurance.html',
#  '/insurance/manage-your-insurance-policy.html?pid=vis:meganav:setup-car:ins',
#  'https://health.ing.com.au/onlineservices',
#  '/insurance/car-insurance.html#ING-content-2',
#  'https://ing.disconline.com.au/retrieve-quote/2.0/?entity=10738&pid=vis:def:raq:carins',
#  '/insurance/claims.html?pid=vis:meganav:car:manage-policy',
#  'https://ing.disconline.com.au/myaccount/#/signin?pid=vis:meganav:car:claim',
#  '/help-and-support/documents-and-forms/insurance.html#Car-Insurance',
#  '/insurance/manage-your-insurance-policy.html?pid=vis:meganav:setup-car:ins',
#  'https://ing.disconline.com.au/car/3/?brand=EXIG&entity=10738&LinkId=13629&pid=vis:meganav:carins:carinsmenu',
#  '/insurance/health-insurance.html#ING-content-2',
#  '/insurance/claims.html?pid=vis:meganav:health:manage-policy',
#  'https://id.health.ing.com.au/login?pid=vis:meganav:health:claim',
#  '/help-and-support/documents-and-forms/insurance.html#Health-Insurance',
#  'https://healthquote.ing.com.au/join/welcome/?pid=vis:meganav:healthins:getaquote',
#  '/insurance/home-and-contents-insurance.html#ING-content-2',
#  'https://ing.disconline.com.au/retrieve-quote/2.0/?entity=10738&pid=vis:meganav:retrieve:ins',
#  '/insurance/claims.html?pid=vis:meganav:home:manage-policy',
#  '/insurance/home-and-contents-insurance.html#ING-content-5',
#  '/help-and-support/documents-and-forms/insurance.html#Home-Contents-Insurance',
#  'https://ing.disconline.com.au/home/3.0/?entity=10738&LinkId=13626&pid=vis:meganav:homeins:homeinsmenu',
#  '/insurance/motorcycle-insurance.html#ING-content-2',
#  'https://ing.disconline.com.au/retrieve-quote/2.0/?entity=10738',
#  '/insurance/claims.html?pid=vis:meganav:motor:manage-policy',
#  '/insurance/motorcycle-insurance.html#ING-content-5',
#  '/help-and-support/documents-and-forms/insurance.html#Motorcycle-Insurance',
#  'https://ing.disconline.com.au/motorcycle/1/?entity=10738&LinkId=13452&pid=vis:meganav:motorins:motorinsmenu',
#  '/insurance/pet-insurance.html#ING-content-2',
#  'https://ing-pet.disconline.com.au/#/quote-retrieval',
#  '/insurance/claims.html?cid=vis:meganav:pet:manage-policy',
#  '/insurance/pet-insurance.html#ING-content-5',
#  '/help-and-support/documents-and-forms/insurance.html#Pet-Insurance',
#  'https://ing-pet.disconline.com.au/?LinkId=14009&pid=vis:meganav:petins:petinsmenu',
#  '/help-and-support/documents-and-forms/insurance.html#Travel-Insurance',
#  '/superannuation/living-super.html',
#  '#menu-superannuation',
#  '#menu-SMSF',
#  '#',
#  '/superannuation/living-super.html',
#  '#',
#  '/superannuation/smsf-cash.html',
#  '/superannuation/smsf-term-deposit.html',
#  '/superannuation/living-super/compare-super-accounts.html',
#  '/superannuation/living-super/compare-investments.html',
#  '/superannuation/tips-hints-guides/shares-etfs-lics.html',
#  '/calculators-and-tools.html#ING-content-4',
#  '/rates-and-fees/superannuation-rates.html',
#  '/superannuation/living-super/compare-super-accounts.html',
#  '/superannuation/living-super/compare-investments.html',
#  '/superannuation/tips-hints-guides/shares-etfs-lics.html',
#  '/calculators-and-tools.html#ING-content-4',
#  '/rates-and-fees/superannuation-rates.html',
#  '/about-us.html',
#  '/contact-us.html',
#  '/help-and-support.html',
#  '/security.html',
#  'javascript:openJointInviteModal()',
#  'https://campaigns.ing.com.au/everyday-banking?pid=vis:hph:ca-ching',
#  '/help-and-support/extra-care-and-support.html?pid=vis:hph1:extrasupport',
#  '/help-and-support/tips-hints-guides/financial-hardship.html?pid=vis:hph3:rdsgn2023:finsupport',
#  'https://www.ing.com.au/help-and-support/tips-hints-guides/KYC.html',
#  'https://www.ing.com.au/everyday-banking/utility-bill-cashback.html',
#  'https://www.ing.com.au/pdf/Orange_Everyday_Terms_and_Conditions.pdf',
#  'everyday-banking.html',
#  '/savings/savings-maximiser.html',
#  '/savings.html',
#  '/personal-loans.html',
#  'https://www.ing.com.au/everyday-banking/utility-bill-cashback.html',
#  'https://www.ing.com.au/pdf/Orange_Everyday_Terms_and_Conditions.pdf',
#  'everyday-banking.html',
#  '/credit-cards.html',
#  '/credit-cards/compare-credit-cards.html',
#  '/home-loans.html',
#  '/insurance/home-and-contents-insurance.html',
#  '/superannuation/living-super.html',
#  '/savings/savings-maximiser.html',
#  '/savings.html',
#  '/business/business-optimiser.html',
#  '/business.html',
#  '/home-loans/commercial-loan.html',
#  '/everyday-banking.html',
#  '/savings/savings-maximiser.html',
#  '/savings.html',
#  '/business/business-optimiser.html',
#  '/business.html',
#  '/credit-cards/orange-one.html',
#  '/credit-cards/orange-one-platinum.html',
#  '/credit-cards.html',
#  '/personal-loans.html',
#  '/home-loans/orange-advantage.html',
#  '/home-loans/fixed-rate-home-loan.html',
#  '/home-loans.html',
#  '/home-loans/commercial-loan.html#content-1',
#  '/home-loans/commercial-loan.html#content-2',
#  '/insurance/health-insurance.html',
#  '/insurance/home-and-contents-insurance.html',
#  '/insurance/home-and-contents-insurance.html',
#  '/insurance/home-and-contents-insurance.html',
#  '/insurance/car-insurance.html',
#  '/insurance/pet-insurance.html',
#  '/insurance/motorcycle-insurance.html',
#  '/superannuation/living-super.html',
#  '/superannuation/smsf-cash.html',
#  '/superannuation/smsf-term-deposit.html',
#  'https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en',
#  'javascript:openJointInviteModal()',
#  '/ways-to-bank.html#ING-content-1',
#  '/ways-to-bank.html#ING-content-1',
#  '/mobile-banking.html',
#  '/mobile-banking.html',
#  '/ways-to-bank.html#ING-content-3',
#  '/ways-to-bank.html#ING-content-3',
#  '/ways-to-bank.html#ING-content-5',
#  '/ways-to-bank.html#ING-content-5',
#  '/ways-to-bank.html#ING-content-6',
#  '/ways-to-bank.html#ING-content-6',
#  '/ways-to-bank.html#ING-content-7',
#  '/ways-to-bank.html#ING-content-7',
#  '/ways-to-bank.html',
#  '/help-and-support/tips-hints-guides/financial-hardship.html',
#  '/accessibility.html',
#  '/pdf/Banking_Code_of_Practice.pdf',
#  '/help-and-support/tips-hints-guides/financial-hardship.html',
#  '/accessibility.html',
#  '/pdf/Banking_Code_of_Practice.pdf',
#  'https://campaigns.ing.com.au/doyourthing',
#  'https://blog.ing.com.au/money-matters/saving/how-to-embrace-money-minimalism/',
#  'https://blog.ing.com.au/money-matters/saving/how-to-be-rainy-day-ready?utm_medium=Visitor-site&utm_source=Visitor-home-carousel&utm_campaign=Content-carousel',
#  'https://blog.ing.com.au/house-and-home/buy/understand-your-borrowing-power?utm_medium=Visitor-site&utm_source=Visitor-home-carousel&utm_campaign=Content-carousel',
#  'https://blog.ing.com.au/house-and-home/?utm_medium=Visitor-site&utm_source=Visitor-home-carousel&utm_campaign=Content-carousel',
#  'https://blog.ing.com.au/money-matters/saving/wedding-season-is-back-on/?utm_medium=Visitor-site&utm_source=Visitor-home-carousel&utm_campaign=Content-carousel',
#  'https://www.ing.com.au/rates-and-fees/home-loan-reference-rates.html',
#  '/help-and-support/documents-and-forms/home-loans.html',
#  '/pdf/Orange_Everyday_Terms_and_Conditions.pdf ',
#  '/pdf/Orange_Everyday_Fees_and_Limits_Schedule.pdf',
#  '/pdf/ING_OE_TMD.pdf',
#  '/pdf/SM_Terms_and_Conditions.pdf',
#  '/pdf/Orange_Everyday_Terms_and_Conditions.pdf',
#  '/pdf/Orange_Everyday_Fees_and_Limits_Schedule.pdf',
#  'https://www.ing.com.au/help-and-support/documents-and-forms/insurance.html',
#  'https://www.redbook.com.au',
#  'https://www.glassguide.com.au',
#  'https://www.ing.com.au/help-and-support/documents-and-forms/insurance.html',
#  '/index.html',
#  '/help-and-support.html',
#  '/faq-landing.html?product=General',
#  '/help-and-support/documents-and-forms/general.html',
#  '/help-and-support/tips-hints-guides/general.html',
#  '/help-and-support/tips-hints-guides/financial-hardship.html',
#  '/ways-to-bank.html',
#  'https://www.ing.com.au/open-banking.html',
#  '/calculators-and-tools.html',
#  '/savings/calculators/savings.html',
#  '/home-loans/calculators/repayments.html',
#  '/home-loans/calculators/borrowing-power.html',
#  '/personal-loans/calculators/personal-loan-borrowing-power-calculator.html',
#  '/personal-loans/calculators/personal-loan-repayments-calculator.html',
#  '/rates-and-fees.html',
#  '/rates-and-fees/savings-interest-rates.html',
#  '/rates-and-fees/credit-cards-rates.html',
#  '/rates-and-fees/personal-loan-rates.html',
#  '/rates-and-fees/home-loan-rates.html',
#  '/rates-and-fees/superannuation-rates.html',
#  '/mobile-banking.html',
#  '/contact-us.html',
#  'https://apps.apple.com/au/app/ing-australia-banking/id427100193',
#  'https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU',
#  'https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU',
#  'https://www.tiktok.com/@ing_aust',
#  'https://www.facebook.com/INGAust/',
#  'https://youtube.com/c/INGaust',
#  'https://helphub.ing.com.au/',
#  'https://au.linkedin.com/company/ing-australia',
#  'https://www.instagram.com/ing_aust/',
#  'https://x.com/ing_aust?lang=en',
#  'https://apps.apple.com/au/app/ing-australia-banking/id427100193',
#  'https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU',
#  'https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU',
#  '/about-us.html',
#  '/contact-us.html',
#  'https://www.ing.jobs/Australia/Home.htm',
#  '/security.html',
#  '/privacy.html',
#  '/legal.html',
#  '/sitemap.html',
#  'https://www.ing.com.au/pdf/ING_Reconciliation_Action_Plan.pdf',
#  '/help-and-support/documents-and-forms/insurance.html',
#  '/help-and-support/documents-and-forms/insurance.html']

# %% [markdown]
# ## First step: Have GPT-5-nano figure out which links are relevant
#
# ### Use a call to gpt-5-nano to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = """
You are provided with a list of links found on a webpage.
You are able to decide which of the links would be most relevant to include in a brochure about the company,
such as links to an About page, or a Company page, or Careers/Jobs pages.
You should respond in JSON as in this example:

{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(url):
    user_prompt = f"""
Here is the list of links on the website {url} -
Please decide which of these are relevant web links for a brochure about the company, 
respond with the full https URL in JSON format.
Do not include Terms of Service, Privacy, email links.

Links (some might be relative links):

"""
    links = fetch_website_links(url)
    user_prompt += "\n".join(links)
    return user_prompt

# %%
print(get_links_user_prompt("https://www.ing.com.au"))
# Out:
# Here is the list of links on the website https://www.ing.com.au -
# Please decide which of these are relevant web links for a brochure about the company,
# respond with the full https URL in JSON format.
# Do not include Terms of Service, Privacy, email links.
#
# Links (some might be relative links):
#
# /index.html
# #
# #
# #
# #
# #
# javascript:openJointInviteModal()
# /securebanking/
# javascript:openJointInviteModal()
# /everyday-banking.html
# #menu-everyday-banking
# #menu-personal-savings
# #menu-business-savings
# #
# /everyday-banking.html
# #
# /savings.html
# /savings/savings-maximiser.html
# /savings/term-deposit.html
# /savings/savings-accelerator.html
# #
# /business.html
# /business/business-optimiser.html
# /business/term-deposit.html
# /business/wholesale-term-deposit.html
# /savings/budgeting-planning.html
# /everyday-banking.html#ING-content-5
# /mobile-banking.html
# /savings/budgeting-strategy.html
# /everyday-banking/everyday-round-up.html
# /everyday-banking/pay-id.html
# /everyday-banking/card-management.html
# /savings/budgeting-planning.html
# /savings.html#ING-content-2
# /savings/compare-savings.html
# /savings/budgeting-strategy.html
# /calculators-and-tools.html#ING-content-2
# /rates-and-fees/savings-interest-rates.html
# /rates-and-fees/term-deposit-rates.html
# /calculators-and-tools.html#ING-content-2
# /rates-and-fees/business-banking-rates.html
# /credit-cards.html
# /home-loans/calculators/borrowing-power.html
# /personal-loans/calculators/personal-loan-borrowing-power-calculator.html
# /personal-loans/calculators/personal-loan-repayments-calculator.html
# /rates-and-fees.html
# /rates-and-fees/savings-interest-rates.html
# /rates-and-fees/credit-cards-rates.html
# /rates-and-fees/personal-loan-rates.html
# /rates-and-fees/home-loan-rates.html
# /rates-and-fees/superannuation-rates.html
# /mobile-banking.html
# /contact-us.html
# https://apps.apple.com/au/app/ing-australia-banking/id427100193
# https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU
# https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU
# https://www.tiktok.com/@ing_aust
# https://www.facebook.com/INGAust/
# https://youtube.com/c/INGaust
# https://helphub.ing.com.au/
# https://au.linkedin.com/company/ing-australia
# https://www.instagram.com/ing_aust/
# https://x.com/ing_aust?lang=en
# https://apps.apple.com/au/app/ing-australia-banking/id427100193
# https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU
# https://play.google.com/store/apps/details?id=au.com.ingdirect.android&hl=en_AU
# /about-us.html
# /contact-us.html
# https://www.ing.jobs/Australia/Home.htm
# /security.html
# /privacy.html
# /legal.html
# /sitemap.html
# https://www.ing.com.au/pdf/ING_Reconciliation_Action_Plan.pdf
# /help-and-support/documents-and-forms/insurance.html
# /help-and-support/documents-and-forms/insurance.html

# %%
def select_relevant_links(url):
    response = ollama.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    return links

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
MODEL = "gemma3:latest"

# %%
select_relevant_links("https://www.ing.com.au")
# Out:
# {}

# %%
def select_relevant_links(url):
    print(f"Selecting relevant links for {url} by calling {MODEL}")
    response = ollama.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    print(f"Found {len(links['links'])} relevant links")
    return links

# %%
select_relevant_links("https://www.ing.com.au")

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT-5-nano

# %%
def fetch_page_and_all_relevant_links(url):
    contents = fetch_website_contents(url)
    relevant_links = select_relevant_links(url)
    result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
    for link in relevant_links['links']:
        result += f"\n\n### Link: {link['type']}\n"
        result += fetch_website_contents(link["url"])
    return result

# %%
print(fetch_page_and_all_relevant_links("https://www.ing.com.au"))

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# brochure_system_prompt = """
# You are an assistant that analyzes the contents of several relevant pages from a company website
# and creates a short, humorous, entertaining, witty brochure about the company for prospective customers, investors and recruits.
# Respond in markdown without code blocks.
# Include details of company culture, customers and careers/jobs if you have the information.
# """

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a company called: {company_name}
Here are the contents of its landing page and other relevant pages;
use this information to build a short brochure of the company in markdown without code blocks.\n\n
"""
    user_prompt += fetch_page_and_all_relevant_links(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("ING", "https://www.ing.com.au")

# %%
def create_brochure(company_name, url):
    response = ollama.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("ING", "https://www.ing.com.au")

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [raw]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
