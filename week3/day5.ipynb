# %% [markdown]
# # Meeting minutes creator
#
# In this colab, we make a meeting minutes program.
#
# It includes useful code to connect your Google Drive to your colab.
#
# Upload your own audio to make this work!!
#
# https://colab.research.google.com/drive/1KSMxOCprsl1QRpt_Rq0UqCAyMtPqDQYx?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# ### BUT FIRST - Something cool - really showing you how "model inference" works via OpenAI

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/yniu/mypython13/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yniu/mypython13/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/yniu/mypython13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from visualizer import TokenPredictor, create_token_graph, visualize_predictions

message = "In one sentence, describe the most important news in 2025"
model_name = "gpt-4.1-mini"

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predictions)
plt = visualize_predictions(G)
plt.show()
# Out:
# /home/yniu/mypython13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 2536 (\N{BENGALI DIGIT TWO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yniu/mypython13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yniu/mypython13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yniu/mypython13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 65301 (\N{FULLWIDTH DIGIT FIVE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
